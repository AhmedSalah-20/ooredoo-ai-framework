# %%
# notebooks/1_llm_pipeline.ipynb
# CELLULE 1

from src.unified_pipeline import UnifiedPipeline

pipeline = UnifiedPipeline()
train, test = pipeline.prepare_llm()

print(f"✅ Train: {len(train)} | Test: {len(test)}")

# %%
# notebooks/1_llm_pipeline.ipynb
# CELLULE 2

pipeline = UnifiedPipeline()
trainer = pipeline.train_llm()

print("✅ LLM training complete!")

# %%
# notebooks/1_llm_pipeline.ipynb
# CELLULE 3 (Test Inference)

from src.unified_pipeline import UnifiedPipeline

pipeline = UnifiedPipeline()

text = "السلام عليكم"
response = pipeline.inference_llm(text)

print(f"Input: {text}")
print(f"Output: {response}")
